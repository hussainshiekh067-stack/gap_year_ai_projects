# %%
# Core libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %%
# Manual dataset using SAT, GPA, Research
data = pd.DataFrame({
    "SAT": [1200, 1250, 1300, 1350, 1400, 1450, 1280, 1320],
    "GPA": [3.0, 3.2, 3.5, 3.6, 3.8, 3.9, 3.4, 3.7],
    "Research": [0, 0, 1, 0, 1, 1, 0, 1],
    "Chance": [0.55, 0.60, 0.70, 0.75, 0.85, 0.90, 0.65, 0.80]
})

data.head()
# Out:
#     SAT  GPA  Research  Chance
# 0  1200  3.0         0    0.55
# 1  1250  3.2         0    0.60
# 2  1300  3.5         1    0.70
# 3  1350  3.6         0    0.75
# 4  1400  3.8         1    0.85

# %%
# Inputs (X) and output (y)
X = data.drop("Chance", axis=1)
y = data["Chance"]

X.head(), y.head()
# Out:
# (    SAT  GPA  Research
#  0  1200  3.0         0
#  1  1250  3.2         0
#  2  1300  3.5         1
#  3  1350  3.6         0
#  4  1400  3.8         1,
#  0    0.55
#  1    0.60
#  2    0.70
#  3    0.75
#  4    0.85
#  Name: Chance, dtype: float64)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

X_train.shape, X_test.shape
# Out:
# ((6, 3), (2, 3))

# %%
model = LinearRegression()
model.fit(X_train, y_train)

print("Model trained successfully")
# Out:
# Model trained successfully

# %%
predictions = model.predict(X_test)
predictions
# Out:
# array([0.60567452, 0.88972163])

# %%
score = r2_score(y_test, predictions)
print(f"R² Score: {score:.3f}")
# Out:
# R² Score: 0.997

# %%
plt.scatter(y_test, predictions)
plt.xlabel("Actual Chance of Admit")
plt.ylabel("Predicted Chance of Admit")
plt.title("Actual vs Predicted")
plt.show()

# %%
# Input your real profile
my_profile = pd.DataFrame({
    "SAT": [1360],     # Your actual SAT score
    "GPA": [3.74],     # Your GPA
    "Research": [1]    # 1 = AI project / initiative
})

chance = model.predict(my_profile)
chance_percent = chance[0]*100

print("==========================================")
print(f"💡 Based on this AI model, my predicted chance of admission is: {chance_percent:.1f}%")
print("This prediction is calculated using my own profile and dataset created manually.")
print("==========================================")
# Out:
# ...
# 💡 Based on this AI model, my predicted chance of admission is: 81.0%
# This prediction is calculated using my own profile and dataset created manually.
# ...

# %% [markdown]
# # Notes
# - Dataset is manually created for demonstration purposes.
# - Model demonstrates complete ML workflow: data -> train/test -> prediction -> evaluation.
# - I used this model to calculate my own admission chances, showing originality and understanding.
# - Small dataset limits generalizability; purpose is to showcase initiative and CS/AI skills.
# - This project can be used in gap-year portfolio / GitHub / University applications.
